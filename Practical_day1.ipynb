# %%
print('Hello world!')
# Out:
# Hello world!

# %%
x=2
x
# Out:
# 2

# %%
x**3
# Out:
# 8

# %%
list1=['a', 'b', 'c', 'd']
list2=['w', 'x', 'y', 'z']
list1 + list2
# Out:
# ['a', 'b', 'c', 'd', 'w', 'x', 'y', 'z']

# %%
A=range(1,10,2)
